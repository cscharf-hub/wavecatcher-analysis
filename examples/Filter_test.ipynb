# %% [markdown]
# # Example for filter functions

# %%
import ROOT
import os
import numpy as np
# %jsroot on
# Get the path of wavecatcher analysis and load the shared library
if 'dir' not in locals():
    os.chdir('..')
dir = os.getcwd()
ROOT.gSystem.Load(dir + '/ReadRunLib.sl')
ROOT.gStyle.SetOptStat("ne"); ROOT.gStyle.SetOptFit(1111); ROOT.gStyle.SetOptTitle(0)
print('The current working directory is ' + dir + '.')
print('Please make sure it is the folder containing wavecatcher-analysis.')
# Out:
# Welcome to JupyROOT 6.28/00
# The current working directory is /mnt/c/SHiP.
# Please make sure it is the folder containing wavecatcher-analysis.

# %%
# parameters for analysis
baseline_pars = ROOT.std.vector('double')([25, 30, 100])

intwindowminus = 10.
intwindowplus = 50.
findmaxfrom = 100.
findmaxto = 130.
ymin = -5
ymax = 35;

# plot only channel 2 for better visibility
plot_channels = ROOT.std.vector('int')([2])

# save every 5th waveform
step = 5

# investigate one particular waveform (multiple of step)
waveform_number = '270'

# %%
mymeas = ROOT.ReadRun(0)
mymeas.ReadFile(dir + '/examples/exampledata/timingdata/', True, 0, 'examples/filter_results.root')
mymeas.plot_active_channels = plot_channels

# gaussian smoothing filter with sigma=0.5 ns for better visibility 
mymeas.SmoothAll(.5, 'Gaus')

# CorrectBaselineMin() is better suited for this data, try CorrectBaselineMinSlopeRMS() to see what goes wrong
mymeas.CorrectBaselineMin(baseline_pars)
#mymeas.CorrectBaselineMinSlopeRMS(baseline_pars)

for eventnr in range(0, mymeas.nevents, step):
    mymeas.PrintChargeSpectrumWF(intwindowminus, intwindowplus, findmaxfrom, findmaxto, eventnr, ymin, ymax)

del mymeas
# Out:
# initializing ...
# +++ saving analysis results in 'examples/filter_results.root' ...
#
# +++ reading '/mnt/c/SHiP/examples/exampledata/timingdata/timingdata.bin' ...
#
# start at ch 0 end at ch 3
# Finished reading 1 files containing 500 events with 4 channels.
#
#
# Smoothing all non-skipped waveforms:
# [##################################################] 100%
#
#
# Baseline correction (minimal sum method, 2000 waveforms):
# [##################################################] 100%
#
#
# deleting nothing currently...

# %%
mymeas2 = ROOT.ReadRun(0)
mymeas2.ReadFile(dir + '/examples/exampledata/timingdata/', True, 0, 'examples/filter_results_filtered.root')
mymeas2.plot_active_channels = plot_channels

# apply filter to suppress the slow tail of the peaks
mymeas2.FilterAll(.5, 5.5, .075)

mymeas2.CorrectBaselineMin(baseline_pars)

for eventnr in range(0, mymeas2.nevents, step):
    mymeas2.PrintChargeSpectrumWF(intwindowminus, intwindowplus, findmaxfrom, findmaxto, eventnr, ymin, ymax)

del mymeas2
# Out:
# initializing ...
# +++ saving analysis results in 'examples/filter_results_filtered.root' ...
#
# +++ reading '/mnt/c/SHiP/examples/exampledata/timingdata/timingdata.bin' ...
#
# start at ch 0 end at ch 3
# Finished reading 1 files containing 500 events with 4 channels.
#
#
# Filtering all waveforms
# [##################################################] 100%
#
#
# Baseline correction (minimal sum method, 2000 waveforms):
# [##################################################] 100%
#
#
# deleting nothing currently...
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00000
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00005
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00010
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00015
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00020
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00025
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00030
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00035
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00040
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00045
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00050
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00055
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00060
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00065
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00070
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00075
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00080
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00085
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00090
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00095
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00100
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00105
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00110
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00115
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00120
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00125
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00130
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00135
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00140
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00145
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00150
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00155
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00160
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00165
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00170
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00175
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00180
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00185
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00190
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00195
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00200
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00205
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00210
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00215
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00220
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00225
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00230
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00235
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00240
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00245
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00250
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00255
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00260
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00265
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00270
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00275
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00280
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00285
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00290
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00295
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00300
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00305
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00310
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00315
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00320
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00325
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00330
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00335
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00340
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00345
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00350
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00355
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00360
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00365
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00370
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00375
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00380
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00385
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00390
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00395
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00400
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00405
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00410
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00415
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00420
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00425
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00430
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00435
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00440
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00445
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00450
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00455
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00460
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00465
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00470
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00475
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00480
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00485
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00490
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: waveforms_event__00495

# %%
data = ROOT.TFile(dir + '/examples/filter_results.root', 'read')
canv = data.Get('waveforms_event__00' + waveform_number)
data.Close()
canv.Draw()
# Out:
# <div id="root_plot_1694533635575"
#      style="width: 592px; height: 344px">
# </div>
# <script>
#
# function display_root_plot_1694533635575(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.15,"fRightMargin":0.01,"fBottomMargin":0.1,"fTopMargin":0.01,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-57.2991071428571,"fY1":-9.49438216168236,"fX2":323.653273572997,"fY2":35.4494381994254,"fXtoAbsPixelk":89.042862555285,"fXtoPixelk":89.042862555285,"fXtoPixel":1.55400000096485,"fYtoAbsPixelk":271.330049155011,"fYtoPixelk":271.330049155011,"fYtoPixel":-7.65399997677282,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":592,"fVtoAbsPixelk":344.00005,"fVtoPixelk":344,"fVtoPixel":-344,"fAbsPixeltoXk":-57.2991071428571,"fPixeltoXk":-57.2991071428571,"fPixeltoX":0.643500643101106,"fAbsPixeltoYk":35.4494381994254,"fPixeltoYk":-9.49438216168236,"fPixeltoY":-0.130650640584615,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":-0.15625,"fUymin":-5,"fUxmax":319.84375,"fUymax":35,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":true,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":-0.15625,"fY1":-5,"fX2":319.84375,"fY2":35,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":513,"fName":"channel02_event00270","fTitle":"Channel 2, event 270","fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":1026,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"time [ns]","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1024,"fXmin":-0.15625,"fXmax":319.84375,"fXbins":[],"fFirst":1,"fLast":1,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"signal [mV]","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":3072,"fTsumw":0,"fTsumw2":0,"fTsumwx":0,"fTsumwx2":0,"fMaximum":35,"fMinimum":-5,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fBufferSize":0,"fBuffer":[],"fBinStatErrOpt":0,"fStatOverflows":2,"fArray":{"$arr":"Float32","len":1026,"p":1,"v":[-0.6064812,-0.6434458,-0.6553377,-0.6592473,-0.6911503,-0.7757363,-0.9137436,-1.066308,-1.144005,-1.054091,-0.8007174,-0.5199606,-0.3757019,-0.4219224,-0.5864676,-0.7431908,-0.7977003,-0.7416829,-0.6482111,-0.5988684,-0.6277757,-0.7070765,-0.7771931,-0.7917547,-0.7674888,-0.7800418,-0.84943,-0.8602209,-0.7299633,-0. ...

# %%
data2 = ROOT.TFile(dir + '/examples/filter_results_filtered.root', 'read')
canv2 = data2.Get('waveforms_event__00' + waveform_number)
data2.Close()
canv2.Draw()
# Out:
# <div id="root_plot_1694533635722"
#      style="width: 592px; height: 344px">
# </div>
# <script>
#
# function display_root_plot_1694533635722(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.15,"fRightMargin":0.01,"fBottomMargin":0.1,"fTopMargin":0.01,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-57.2991071428571,"fY1":-9.49438216168236,"fX2":323.653273572997,"fY2":35.4494381994254,"fXtoAbsPixelk":89.042862555285,"fXtoPixelk":89.042862555285,"fXtoPixel":1.55400000096485,"fYtoAbsPixelk":271.330049155011,"fYtoPixelk":271.330049155011,"fYtoPixel":-7.65399997677282,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":592,"fVtoAbsPixelk":344.00005,"fVtoPixelk":344,"fVtoPixel":-344,"fAbsPixeltoXk":-57.2991071428571,"fPixeltoXk":-57.2991071428571,"fPixeltoX":0.643500643101106,"fAbsPixeltoYk":35.4494381994254,"fPixeltoYk":-9.49438216168236,"fPixeltoY":-0.130650640584615,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":-0.15625,"fUymin":-5,"fUxmax":319.84375,"fUymax":35,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":true,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":-0.15625,"fY1":-5,"fX2":319.84375,"fY2":35,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":513,"fName":"channel02_event00270","fTitle":"Channel 2, event 270","fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":1026,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"time [ns]","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1024,"fXmin":-0.15625,"fXmax":319.84375,"fXbins":[],"fFirst":1,"fLast":1,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"signal [mV]","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":3072,"fTsumw":0,"fTsumw2":0,"fTsumwx":0,"fTsumwx2":0,"fMaximum":35,"fMinimum":-5,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fBufferSize":0,"fBuffer":[],"fBinStatErrOpt":0,"fStatOverflows":2,"fArray":{"$arr":"Float32","len":1026,"p":1,"v":[0.01839184,-0.06939295,-0.1333134,-0.1432616,-0.1511259,-0.2163547,-0.3481175,-0.5435634,-0.6847554,-0.6233599,-0.3396932,-0.001862466,0.2447512,0.2299117,0.06432787,-0.1397706,-0.210881,-0.1790121,-0.02444996,0.02684253,0.05489993,-0.04951364,-0.140143,-0.1384346,-0.07229918,-0.1034821,-0.1976447,-0.2223018,-0.0617 ...
